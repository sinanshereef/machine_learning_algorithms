# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
af=pd.read_csv("C:/Users/zinan/OneDrive/Documents/adult.csv")
af
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
af.shape
# Out:
# (48842, 15)

# %%
af.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
af.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
af.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
af.head(2)
# Out:
#    age workclass  fnlwgt education  educational-num      marital-status  \
# 0   25   Private  226802      11th                7       Never-married
# 1   38   Private   89814   HS-grad                9  Married-civ-spouse
#
#           occupation relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black   Male             0             0
# 1    Farming-fishing      Husband  White   Male             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K

# %%
af.tail(2)
# Out:
#        age     workclass  fnlwgt education  educational-num  \
# 48840   22       Private  201490   HS-grad                9
# 48841   52  Self-emp-inc  287927   HS-grad                9
#
#            marital-status       occupation relationship   race  gender  \
# 48840       Never-married     Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse  Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K

# %%
af.isna().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
af.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
af['workclass'].unique()
# Out:
# array(['Private', 'Local-gov', '?', 'Self-emp-not-inc', 'Federal-gov',
#        'State-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
workclass=af['workclass']
af['workclass']=lab.fit_transform(workclass)
af['workclass']
# Out:
# 0        4
# 1        4
# 2        2
# 3        4
# 4        0
#         ..
# 48837    4
# 48838    4
# 48839    4
# 48840    4
# 48841    5
# Name: workclass, Length: 48842, dtype: int64

# %%
education=af['education']
af['education']=lab.fit_transform(education)
af['education']
# Out:
# 0         1
# 1        11
# 2         7
# 3        15
# 4        15
#          ..
# 48837     7
# 48838    11
# 48839    11
# 48840    11
# 48841    11
# Name: education, Length: 48842, dtype: int64

# %%
marital_status=af['marital-status']
af['marital-status']=lab.fit_transform(marital_status)
af['marital-status']
# Out:
# 0        4
# 1        2
# 2        2
# 3        2
# 4        4
#         ..
# 48837    2
# 48838    2
# 48839    6
# 48840    4
# 48841    2
# Name: marital-status, Length: 48842, dtype: int64

# %%
occupation=af['occupation']
af['occupation']=lab.fit_transform(occupation)
af['occupation']
# Out:
# 0         7
# 1         5
# 2        11
# 3         7
# 4         0
#          ..
# 48837    13
# 48838     7
# 48839     1
# 48840     1
# 48841     4
# Name: occupation, Length: 48842, dtype: int64

# %%
relationship=af['relationship']
af['relationship']=lab.fit_transform(relationship)
af['relationship']
# Out:
# 0        3
# 1        0
# 2        0
# 3        0
# 4        3
#         ..
# 48837    5
# 48838    0
# 48839    4
# 48840    3
# 48841    5
# Name: relationship, Length: 48842, dtype: int64

# %%
race=af['race']
af['race']=lab.fit_transform(race)
af['race']
# Out:
# 0        2
# 1        4
# 2        4
# 3        2
# 4        4
#         ..
# 48837    4
# 48838    4
# 48839    4
# 48840    4
# 48841    4
# Name: race, Length: 48842, dtype: int64

# %%
gender=af['gender']
af['gender']=lab.fit_transform(gender)
af['gender']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 48837    0
# 48838    1
# 48839    0
# 48840    1
# 48841    0
# Name: gender, Length: 48842, dtype: int64

# %%
native_country=af['native-country']
af['native-country']=lab.fit_transform(native_country)
af['native-country']
# Out:
# 0        39
# 1        39
# 2        39
# 3        39
# 4        39
#          ..
# 48837    39
# 48838    39
# 48839    39
# 48840    39
# 48841    39
# Name: native-country, Length: 48842, dtype: int64

# %%
af.dtypes
# Out:
# age                 int64
# workclass           int64
# fnlwgt              int64
# education           int64
# educational-num     int64
# marital-status      int64
# occupation          int64
# relationship        int64
# race                int64
# gender              int64
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country      int64
# income             object
# dtype: object

# %%
af1=af['income'].value_counts()
af1
# Out:
# income
# <=50K    37155
# >50K     11687
# Name: count, dtype: int64

# %%
plt.bar(af1.index,af1.values)
plt.xlabel('index')
plt.ylabel('values')
# Out:
# Text(0, 0.5, 'values')

# %%
x=af.iloc[:,:-1].values
y=af.iloc[:,-1].values
x
# Out:
# array([[    25,      4, 226802, ...,      0,     40,     39],
#        [    38,      4,  89814, ...,      0,     50,     39],
#        [    28,      2, 336951, ...,      0,     40,     39],
#        ...,
#        [    58,      4, 151910, ...,      0,     40,     39],
#        [    22,      4, 201490, ...,      0,     20,     39],
#        [    52,      5, 287927, ...,      0,     40,     39]],
#       shape=(48842, 14))

# %%
y
# Out:
# array(['<=50K', '<=50K', '>50K', ..., '<=50K', '<=50K', '>50K'],
#       shape=(48842,), dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)
x_train
# Out:
# array([[    43,      4, 393762, ...,      0,     35,     39],
#        [    58,      4, 201393, ...,   1876,     40,     39],
#        [    38,      2, 200153, ...,      0,     40,     39],
#        ...,
#        [    18,      4, 179597, ...,      0,     20,     39],
#        [    46,      4, 145290, ...,      0,     40,     39],
#        [    24,      4, 376393, ...,      0,     40,     39]],
#       shape=(34189, 14))

# %%
y_train
# Out:
# array(['<=50K', '<=50K', '<=50K', ..., '<=50K', '>50K', '<=50K'],
#       shape=(34189,), dtype=object)

# %%
x_test
# Out:
# array([[    31,      4, 224234, ...,      0,     40,     39],
#        [    25,      4, 149486, ...,      0,     40,     39],
#        [    36,      6, 343721, ...,      0,     30,      0],
#        ...,
#        [    39,      4, 262158, ...,      0,     45,     39],
#        [    52,      2, 155233, ...,      0,     28,     39],
#        [    33,      4, 243674, ...,      0,     46,     39]],
#       shape=(14653, 14))

# %%
y_test
# Out:
# array(['<=50K', '<=50K', '>50K', ..., '<=50K', '<=50K', '<=50K'],
#       shape=(14653,), dtype=object)

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
scalar.fit(x_train)
x_train=scalar.transform(x_train)
x_test=scalar.transform(x_test)
x_train
# Out:
# array([[ 0.32075734,  0.08751792,  1.92722719, ..., -0.21585553,
#         -0.43518866,  0.29013795],
#        [ 1.41527855,  0.08751792,  0.10874339, ...,  4.48711264,
#         -0.02926444,  0.29013795],
#        [-0.04408306, -1.27844881,  0.09702154, ..., -0.21585553,
#         -0.02926444,  0.29013795],
#        ...,
#        [-1.50344467,  0.08751792, -0.09729643, ..., -0.21585553,
#         -1.65296132,  0.29013795],
#        [ 0.53966158,  0.08751792, -0.421604  , ..., -0.21585553,
#         -0.02926444,  0.29013795],
#        [-1.06563618,  0.08751792,  1.76303626, ..., -0.21585553,
#         -0.02926444,  0.29013795]], shape=(34189, 14))

# %%
x_test
# Out:
# array([[-0.55485962,  0.08751792,  0.32466169, ..., -0.21585553,
#         -0.02926444,  0.29013795],
#        [-0.9926681 ,  0.08751792, -0.38193878, ..., -0.21585553,
#         -0.02926444,  0.29013795],
#        [-0.19001922,  1.45348465,  1.4541845 , ..., -0.21585553,
#         -0.84111288, -4.74397523],
#        ...,
#        [ 0.02888502,  0.08751792,  0.68316114, ..., -0.21585553,
#          0.37665978,  0.29013795],
#        [ 0.97747007, -1.27844881, -0.32761181, ..., -0.21585553,
#         -1.00348257,  0.29013795],
#        [-0.40892346,  0.08751792,  0.50843   , ..., -0.21585553,
#          0.45784462,  0.29013795]], shape=(14653, 14))

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=7)
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
y_pred
# Out:
# array(['<=50K', '<=50K', '>50K', ..., '<=50K', '<=50K', '<=50K'],
#       shape=(14653,), dtype=object)

# %%
y_test
# Out:
# array(['<=50K', '<=50K', '>50K', ..., '<=50K', '<=50K', '<=50K'],
#       shape=(14653,), dtype=object)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,ConfusionMatrixDisplay
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[10107,  1005],
#        [ 1465,  2076]])

# %%
score=accuracy_score(y_test,y_pred)*100
score
# Out:
# 83.1433836074524

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snd
df=pd.read_csv("C:/Users/zinan/OneDrive/Documents/loan_train.csv")
df
# Out:
#      Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0      Male      No          0      Graduate            No            584900
# 1      Male     Yes          1      Graduate            No            458300
# 2      Male     Yes          0      Graduate           Yes            300000
# 3      Male     Yes          0  Not Graduate            No            258300
# 4      Male      No          0      Graduate            No            600000
# ..      ...     ...        ...           ...           ...               ...
# 609  Female      No          0      Graduate            No            290000
# 610    Male     Yes         3+      Graduate            No            410600
# 611    Male     Yes          1      Graduate            No            807200
# 612    Male     Yes          2      Graduate            No            758300
# 613  Female      No          0      Graduate           Yes            458300
#
# ...

# %%
df.shape
# Out:
# (614, 12)

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'Applicant_Income', 'Coapplicant_Income', 'Loan_Amount', 'Term',
#        'Credit_History', 'Area', 'Status'],
#       dtype='object')

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0   Male      No          0      Graduate            No            584900
# 1   Male     Yes          1      Graduate            No            458300
# 2   Male     Yes          0      Graduate           Yes            300000
# 3   Male     Yes          0  Not Graduate            No            258300
# 4   Male      No          0      Graduate            No            600000
#
#    Coapplicant_Income  Loan_Amount   Term  Credit_History   Area Status
# 0                 0.0     15000000  360.0             1.0  Urban      Y
# 1            150800.0     12800000  360.0             1.0  Rural      N
# 2                 0.0      6600000  360.0             1.0  Urban      Y
# 3            235800.0     12000000  360.0             1.0  Urban      Y
# 4                 0.0     14100000  360.0             1.0  Urban      Y

# %%
df.tail()
# Out:
#      Gender Married Dependents Education Self_Employed  Applicant_Income  \
# 609  Female      No          0  Graduate            No            290000
# 610    Male     Yes         3+  Graduate            No            410600
# 611    Male     Yes          1  Graduate            No            807200
# 612    Male     Yes          2  Graduate            No            758300
# 613  Female      No          0  Graduate           Yes            458300
#
#      Coapplicant_Income  Loan_Amount   Term  Credit_History       Area Status
# 609                 0.0      7100000  360.0             1.0      Rural      Y
# 610                 0.0      4000000  180.0             1.0      Rural      Y
# 611             24000.0     25300000  360.0             1.0      Urban      Y
# 612                 0.0     18700000  360.0             1.0      Urban      Y
# 613                 0.0     13300000  360.0             0.0  Semiurban      N

# %%
df.dtypes
# Out:
# Gender                 object
# Married                object
# Dependents             object
# Education              object
# Self_Employed          object
# Applicant_Income        int64
# Coapplicant_Income    float64
# Loan_Amount             int64
# Term                  float64
# Credit_History        float64
# Area                   object
# Status                 object
# dtype: object

# %%
df.isna().sum()
# Out:
# Gender                13
# Married                3
# Dependents            15
# Education              0
# Self_Employed         32
# Applicant_Income       0
# Coapplicant_Income     0
# Loan_Amount            0
# Term                  14
# Credit_History        50
# Area                   0
# Status                 0
# dtype: int64

# %%
df1=df['Gender'].value_counts()
df1
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
co=['r','g']
plt.bar(df1.index,df1.values,color=co)
plt.xlabel('index')
plt.ylabel('values')
plt.title('gender_obj')
# Out:
# Text(0.5, 1.0, 'gender_obj')

# %%
df2=df['Married'].value_counts()
df2
# Out:
# Married
# Yes    398
# No     213
# Name: count, dtype: int64

# %%
co=['c','k']
plt.bar(df2.index,df2.values,color=co)
plt.xlabel('index')
plt.ylabel('values')
plt.title('married_obj')
# Out:
# Text(0.5, 1.0, 'married_obj')

# %%
df3=df['Education'].value_counts()
df3
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
plt.bar(df3.index,df3.values,color='m')
plt.xlabel('index')
plt.ylabel('values')
plt.title('Graduate_count')
# Out:
# Text(0.5, 1.0, 'Graduate_count')

# %%
df4=df['Self_Employed'].value_counts()
df4
# Out:
# Self_Employed
# No     500
# Yes     82
# Name: count, dtype: int64

# %%
plt.bar(df4.index,df4.values,color='g')
plt.xlabel('index')
plt.ylabel('values')
plt.title('selfemployed_obj')
# Out:
# Text(0.5, 1.0, 'selfemployed_obj')

# %%
df5=df['Area'].value_counts()
df5
# Out:
# Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
plt.pie(df5.values,labels=df5.index,autopct='%2.f%%')
plt.tight_layout()

# %%
df6=df['Status'].value_counts()
df6
# Out:
# Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
plt.bar(df6.index,df6.values)
# Out:
# <BarContainer object of 2 artists>

# %%
df.drop(['Gender'],axis=1,inplace=True)

# %%
df.dtypes
# Out:
# Married                object
# Dependents             object
# Education              object
# Self_Employed          object
# Applicant_Income        int64
# Coapplicant_Income    float64
# Loan_Amount             int64
# Term                  float64
# Credit_History        float64
# Area                   object
# Status                 object
# dtype: object

# %%
df
# Out:
#     Married Dependents     Education Self_Employed  Applicant_Income  \
# 0        No          0      Graduate            No            584900
# 1       Yes          1      Graduate            No            458300
# 2       Yes          0      Graduate           Yes            300000
# 3       Yes          0  Not Graduate            No            258300
# 4        No          0      Graduate            No            600000
# ..      ...        ...           ...           ...               ...
# 609      No          0      Graduate            No            290000
# 610     Yes         3+      Graduate            No            410600
# 611     Yes          1      Graduate            No            807200
# 612     Yes          2      Graduate            No            758300
# 613      No          0      Graduate           Yes            458300
#
#      Coapplicant_Income  Loan_Amount   Term  Credit_History       Area Status
# ...

# %%
#handle missing values
df.isna().sum()
# Out:
# Married                3
# Dependents            15
# Education              0
# Self_Employed         32
# Applicant_Income       0
# Coapplicant_Income     0
# Loan_Amount            0
# Term                  14
# Credit_History        50
# Area                   0
# Status                 0
# dtype: int64

# %%
df['Married'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df['Married']=df['Married'].fillna(df['Married'].mode()[0])

# %%
df['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
df['Dependents']=df['Dependents'].fillna(df['Dependents'].mode()[0])

# %%
df['Self_Employed']=df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
df['Term'].unique()
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
df['Term']=df['Term'].fillna(df['Term'].mode()[0])

# %%
df['Credit_History'].unique()
# Out:
# array([ 1.,  0., nan])

# %%
df['Credit_History']=df['Credit_History'].fillna(df['Credit_History'].mode()[0])

# %%
df.isna().sum()
# Out:
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# Applicant_Income      0
# Coapplicant_Income    0
# Loan_Amount           0
# Term                  0
# Credit_History        0
# Area                  0
# Status                0
# dtype: int64

# %%
df.dtypes
# Out:
# Married                object
# Dependents             object
# Education              object
# Self_Employed          object
# Applicant_Income        int64
# Coapplicant_Income    float64
# Loan_Amount             int64
# Term                  float64
# Credit_History        float64
# Area                   object
# Status                 object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
df['Married']=lab.fit_transform(df['Married'])
df
# Out:
#      Married Dependents     Education Self_Employed  Applicant_Income  \
# 0          0          0      Graduate            No            584900
# 1          1          1      Graduate            No            458300
# 2          1          0      Graduate           Yes            300000
# 3          1          0  Not Graduate            No            258300
# 4          0          0      Graduate            No            600000
# ..       ...        ...           ...           ...               ...
# 609        0          0      Graduate            No            290000
# 610        1         3+      Graduate            No            410600
# 611        1          1      Graduate            No            807200
# 612        1          2      Graduate            No            758300
# 613        0          0      Graduate           Yes            458300
#
#      Coapplicant_Income  Loan_Amount   Term  Credit_History       Area Status
# ...

# %%
df['Dependents']=lab.fit_transform(df['Dependents'])

# %%
df['Education']=lab.fit_transform(df['Education'])

# %%
df['Self_Employed']=lab.fit_transform(df['Self_Employed'])

# %%
df['Area']=lab.fit_transform(df['Area'])

# %%
df
# Out:
#      Married  Dependents  Education  Self_Employed  Applicant_Income  \
# 0          0           0          0              0            584900
# 1          1           1          0              0            458300
# 2          1           0          0              1            300000
# 3          1           0          1              0            258300
# 4          0           0          0              0            600000
# ..       ...         ...        ...            ...               ...
# 609        0           0          0              0            290000
# 610        1           3          0              0            410600
# 611        1           1          0              0            807200
# 612        1           2          0              0            758300
# 613        0           0          0              1            458300
#
#      Coapplicant_Income  Loan_Amount   Term  Credit_History  Area Status
# ...

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values
x
# Out:
# array([[  0.,   0.,   0., ..., 360.,   1.,   2.],
#        [  1.,   1.,   0., ..., 360.,   1.,   0.],
#        [  1.,   0.,   0., ..., 360.,   1.,   2.],
#        ...,
#        [  1.,   1.,   0., ..., 360.,   1.,   2.],
#        [  1.,   2.,   0., ..., 360.,   1.,   2.],
#        [  0.,   0.,   0., ..., 360.,   0.,   1.]], shape=(614, 10))

# %%
y
# Out:
# array(['Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'N', 'N', 'N', 'Y',
#        'Y', 'Y', 'N', 'Y', 'N', 'N', 'N', 'Y', 'N', 'Y', 'N', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'N', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'N',
#        'N', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'N', 'N',
#        'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'N', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'N',
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
x_train
# Out:
# array([[  1.,   0.,   1., ..., 360.,   0.,   2.],
#        [  1.,   0.,   1., ..., 360.,   1.,   0.],
#        [  0.,   0.,   0., ..., 360.,   1.,   1.],
#        ...,
#        [  0.,   0.,   0., ..., 360.,   1.,   2.],
#        [  1.,   0.,   0., ..., 240.,   1.,   1.],
#        [  1.,   0.,   0., ..., 360.,   1.,   2.]], shape=(429, 10))

# %%
x_test
# Out:
# array([[  1.,   0.,   0., ..., 360.,   1.,   1.],
#        [  1.,   0.,   0., ..., 360.,   1.,   1.],
#        [  1.,   2.,   0., ..., 360.,   1.,   0.],
#        ...,
#        [  1.,   2.,   0., ..., 180.,   1.,   2.],
#        [  1.,   0.,   0., ..., 360.,   1.,   0.],
#        [  1.,   0.,   0., ..., 360.,   0.,   0.]], shape=(185, 10))

# %%
y_train
# Out:
# array(['N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N',
#        'N', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'N',
#        'Y', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'N', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'N', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y',
# ...

# %%
y_test
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'N', 'Y', 'Y',
#        'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'N', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'N', 'N', 'Y', 'N', 'N', 'N', 'Y', 'Y', 'N',
#        'N', 'Y', 'N', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'N',
#        'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y',
#        'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N',
#        'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y',
#        'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
# ...

# %% [markdown]
# NO_Scaling/Normalisation is needed in Naive_Bayes.. Because it is not based on Distance

# %%
from sklearn.naive_bayes import MultinomialNB
model=MultinomialNB()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'N', 'N', 'N', 'Y', 'N', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'N',
#        'Y', 'Y', 'Y', 'N', 'N', 'N', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'N', 'Y',
#        'Y', 'Y', 'N', 'N', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'N',
#        'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N',
#        'N', 'N', 'N', 'Y', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
# ...

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,ConfusionMatrixDisplay
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[18, 47],
#        [34, 86]])

# %%
lab=['Y','N']
cmd=ConfusionMatrixDisplay(cm,display_labels=lab)
cmd.plot()

# %%
score=accuracy_score(y_test,y_pred)*100
score
# Out:
# 56.21621621621622
